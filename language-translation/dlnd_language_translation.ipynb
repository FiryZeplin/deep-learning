# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of each sentence from `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def my_text_to_ids(source_text,source_vocab_to_int, target = 0):
    source_id_text = []    
    sentences = source_text.split('\n')
    for sentence in sentences:
        words = sentence.split()
        source_id_sentence = []
        for word in words:
            source_id_sentence.append(source_vocab_to_int[word])

        if target : source_id_sentence.append(source_vocab_to_int['<EOS>'])
        source_id_text.append(list(source_id_sentence))

    return source_id_text
    

def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function
    source_id_text = my_text_to_ids(source_text,source_vocab_to_int)
    target_id_text = my_text_to_ids(target_text,target_vocab_to_int,1)
              
    return (source_id_text, target_id_text)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_encoding_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
#
# Return the placeholders in the following the tuple (Input, Targets, Learing Rate, Keep Probability)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, and learning rate.
    :return: Tuple (input, targets, learning rate, keep probability)
    """
    # TODO: Implement Function
    inputs = tf.placeholder(tf.int32, [None, None], name='input')
    targets = tf.placeholder(tf.int32, [None, None], name='Targets')
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    learning_rate = tf.placeholder(tf.float32, name='learning_rate')
    
    return inputs, targets, learning_rate, keep_prob

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoding Input
# Implement `process_decoding_input` using TensorFlow to remove the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoding_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for dencoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    dec_input = tf.concat([tf.fill([batch_size, 1], target_vocab_to_int['<GO>']), ending], 1)    
    
    return dec_input

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_decoding_input(process_decoding_input)
# Out:
# Tests Passed

# %%
def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :return: RNN state
    """
    # TODO: Implement Function
    
    lstm = tf.contrib.rnn.BasicLSTMCell(rnn_size)
    drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
    cell = tf.contrib.rnn.MultiRNNCell([drop] * num_layers)
    _, state = tf.nn.dynamic_rnn(cell, rnn_inputs, dtype=tf.float32)
    
    return state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create training logits using [`tf.contrib.seq2seq.simple_decoder_fn_train()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_train) and [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder).  Apply the `output_fn` to the [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder) outputs.

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope,
                         output_fn, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param sequence_length: Sequence Length
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Train Logits
    """
    # TODO: Implement Function
    dft = tf.contrib.seq2seq.simple_decoder_fn_train(encoder_state)
    
    tf.contrib.rnn.DropoutWrapper(dec_cell,keep_prob)
    
    outputs, final_state, final_context_state = tf.contrib.seq2seq.dynamic_rnn_decoder(dec_cell, 
                                                   decoder_fn=dft, 
                                                   inputs=dec_embed_input,
                                                   sequence_length=sequence_length,
                                                   scope=decoding_scope)
    logits = output_fn(outputs)
    return logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference logits using [`tf.contrib.seq2seq.simple_decoder_fn_inference()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_inference) and [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder).

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id,
                         maximum_length, vocab_size, decoding_scope, output_fn, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param maximum_length: Maximum length of 
    :param vocab_size: Size of vocabulary
    :param decoding_scope: TensorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Inference Logits
    """
    # TODO: Implement Function
    
    dfi = tf.contrib.seq2seq.simple_decoder_fn_inference(output_fn= output_fn, 
                                                         encoder_state= encoder_state,
                                                         embeddings= dec_embeddings,
                                                         start_of_sequence_id= start_of_sequence_id,
                                                         end_of_sequence_id= end_of_sequence_id,
                                                         maximum_length= maximum_length,
                                                         num_decoder_symbols= vocab_size,
                                                         dtype=tf.int32,
                                                        ) 
    outputs, final_state, final_context_state = tf.contrib.seq2seq.dynamic_rnn_decoder(cell= dec_cell,
                                                                                decoder_fn= dfi,
                                                                                scope= decoding_scope)
    return outputs


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# - Create RNN cell for decoding using `rnn_size` and `num_layers`.
# - Create the output fuction using [`lambda`](https://docs.python.org/3/tutorial/controlflow.html#lambda-expressions) to transform it's input, logits, to class logits.
# - Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope, output_fn, keep_prob)` function to get the training logits.
# - Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, maximum_length, vocab_size, decoding_scope, output_fn, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size,
                   num_layers, target_vocab_to_int, keep_prob):
    """
    Create decoding layer
    :param dec_embed_input: Decoder embedded input
    :param dec_embeddings: Decoder embeddings
    :param encoder_state: The encoded state
    :param vocab_size: Size of vocabulary
    :param sequence_length: Sequence Length
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param keep_prob: Dropout keep probability
    :return: Tuple of (Training Logits, Inference Logits)
    """
    # TODO: Implement Function
    
    rnn = tf.contrib.rnn.BasicLSTMCell(rnn_size)
    
    # Add dropout to the cell
    
    # Stack up multiple LSTM layers, for deep learning
    dec_cell = tf.contrib.rnn.MultiRNNCell([rnn] * num_layers)
    
    output_fn = lambda x: tf.contrib.layers.fully_connected(x,vocab_size,None,scope=decoding_scope)
    with tf.variable_scope("decoding_scope") as decoding_scope:
        output_fn = lambda x: tf.contrib.layers.fully_connected(x,vocab_size,None,scope=decoding_scope)
    with tf.variable_scope("decoding_scope") as decoding_scope:
        logits_T = decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope, output_fn, keep_prob)
    with tf.variable_scope("decoding_scope",reuse=True) as decoding_scope:
        logits_I = decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, target_vocab_to_int['<GO>'], target_vocab_to_int['<EOS>'], sequence_length -1 , vocab_size, decoding_scope, output_fn, keep_prob)
    
    return logits_T, logits_I


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Apply embedding to the input data for the encoder.
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob)`.
# - Process target data using your `process_encoding_input(target_data, target_vocab_to_int, batch_size)` function.
# - Apply embedding to the target data for the decoder.
# - Decode the encoded input using your `decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size, num_layers, target_vocab_to_int, keep_prob)`.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size, sequence_length, source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size, rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param sequence_length: Sequence Length
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training Logits, Inference Logits)
    """
    # TODO: Implement Function
    
    # Encoder embedding
    rnn_inputs = tf.contrib.layers.embed_sequence(input_data, source_vocab_size, enc_embedding_size)
    encoder_state = encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob)
    dec_input = process_decoding_input(target_data, target_vocab_to_int, batch_size)
    
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, dec_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)
    
    ret = decoding_layer(dec_embed_input, dec_embeddings, encoder_state, target_vocab_size, sequence_length, rnn_size, num_layers, target_vocab_to_int, keep_prob)


    return ret


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability

# %%
# Number of Epochs
epochs = 60
# Batch Size
batch_size = 128
# RNN Size
rnn_size = 50
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 13
decoding_embedding_size = 13
# Learning Rate
learning_rate = 0.001
# Dropout Keep Probability
keep_probability = 0.5

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob = model_inputs()
    sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)
    
    train_logits, inference_logits = seq2seq_model(
        tf.reverse(input_data, [-1]), targets, keep_prob, batch_size, sequence_length, len(source_vocab_to_int), len(target_vocab_to_int),
        encoding_embedding_size, decoding_embedding_size, rnn_size, num_layers, target_vocab_to_int)

    tf.identity(inference_logits, 'logits')
    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            train_logits,
            targets,
            tf.ones([input_shape[0], sequence_length]))

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import time

def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target_batch,
            [(0,0),(0,max_seq - target_batch.shape[1]), (0,0)],
            'constant')
    if max_seq - batch_train_logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1]), (0,0)],
            'constant')

    return np.mean(np.equal(target, np.argmax(logits, 2)))

train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]

valid_source = helper.pad_sentence_batch(source_int_text[:batch_size])
valid_target = helper.pad_sentence_batch(target_int_text[:batch_size])

with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    iteration = 1
    
    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch) in enumerate(
                helper.batch_data(train_source, train_target, batch_size)):
            start_time = time.time()
            
            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 sequence_length: target_batch.shape[1],
                 keep_prob: keep_probability})
            
            if iteration%100==0:
                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch, keep_prob: 1.0})
                train_acc = get_accuracy(target_batch, batch_train_logits)
                end_time = time.time()
                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.3f}, Loss: {:>6.3f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, loss))

            if iteration%100==0:
                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_source, keep_prob: 1.0})                
                valid_acc = get_accuracy(np.array(valid_target), batch_valid_logits)

                end_time = time.time()
                print('Epoch {:>3} Batch {:>4}/{} - Validation Accuracy: {:>6.3f}, Loss: {:>6.3f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, valid_acc, loss))

            iteration+=1
    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch   99/1077 - Train Accuracy:  0.266, Loss:  3.317
# Epoch   0 Batch   99/1077 - Validation Accuracy:  0.336, Loss:  3.317
# Epoch   0 Batch  199/1077 - Train Accuracy:  0.339, Loss:  2.863
# Epoch   0 Batch  199/1077 - Validation Accuracy:  0.395, Loss:  2.863
# Epoch   0 Batch  299/1077 - Train Accuracy:  0.389, Loss:  2.530
# Epoch   0 Batch  299/1077 - Validation Accuracy:  0.426, Loss:  2.530
# Epoch   0 Batch  399/1077 - Train Accuracy:  0.372, Loss:  2.633
# Epoch   0 Batch  399/1077 - Validation Accuracy:  0.463, Loss:  2.633
# Epoch   0 Batch  499/1077 - Train Accuracy:  0.436, Loss:  2.261
# Epoch   0 Batch  499/1077 - Validation Accuracy:  0.480, Loss:  2.261
# Epoch   0 Batch  599/1077 - Train Accuracy:  0.422, Loss:  2.245
# Epoch   0 Batch  599/1077 - Validation Accuracy:  0.489, Loss:  2.245
# Epoch   0 Batch  699/1077 - Train Accuracy:  0.400, Loss:  2.241
# Epoch   0 Batch  699/1077 - Validation Accuracy:  0.500, Loss:  2.241
# Epoch   0 Batch  799/1077 - Train Accuracy:  0.445, Loss:  2.031
# Epoch   0 Batch  799/1077 - Validation Accuracy:  0.496, Loss:  2.031
# Epoch   0 Batch  899/1077 - Train Accuracy:  0.469, Loss:  1.789
# Epoch   0 Batch  899/1077 - Validation Accuracy:  0.509, Loss:  1.789
# Epoch   0 Batch  999/1077 - Train Accuracy:  0.456, Loss:  1.674
# Epoch   0 Batch  999/1077 - Validation Accuracy:  0.495, Loss:  1.674
# Epoch   1 Batch   23/1077 - Train Accuracy:  0.453, Loss:  1.549
# Epoch   1 Batch   23/1077 - Validation Accuracy:  0.488, Loss:  1.549
# Epoch   1 Batch  123/1077 - Train Accuracy:  0.484, Loss:  1.355
# Epoch   1 Batch  123/1077 - Validation Accuracy:  0.510, Loss:  1.355
# Epoch   1 Batch  223/1077 - Train Accuracy:  0.478, Loss:  1.222
# Epoch   1 Batch  223/1077 - Validation Accuracy:  0.483, Loss:  1.222
# Epoch   1 Batch  323/1077 - Train Accuracy:  0.489, Loss:  1.155
# Epoch   1 Batch  323/1077 - Validation Accuracy:  0.495, Loss:  1.155
# Epoch   1 Batch  423/1077 - Train Accuracy:  0.475, Loss:  1.160
# Epoch   1 Batch  423/1077 - Validation Accuracy:  0.505, Loss:  1.160
# Epoch   1 Batch  523/1077 - Train Accuracy:  0.430, Loss:  1.092
# Epoch   1 Batch  523/1077 - Validation Accuracy:  0.476, Loss:  1.092
# Epoch   1 Batch  623/1077 - Train Accuracy:  0.479, Loss:  1.034
# Epoch   1 Batch  623/1077 - Validation Accuracy:  0.506, Loss:  1.034
# Epoch   1 Batch  723/1077 - Train Accuracy:  0.501, Loss:  0.959
# Epoch   1 Batch  723/1077 - Validation Accuracy:  0.510, Loss:  0.959
# Epoch   1 Batch  823/1077 - Train Accuracy:  0.513, Loss:  0.950
# Epoch   1 Batch  823/1077 - Validation Accuracy:  0.543, Loss:  0.950
# Epoch   1 Batch  923/1077 - Train Accuracy:  0.465, Loss:  0.953
# Epoch   1 Batch  923/1077 - Validation Accuracy:  0.554, Loss:  0.953
# Epoch   1 Batch 1023/1077 - Train Accuracy:  0.566, Loss:  0.796
# Epoch   1 Batch 1023/1077 - Validation Accuracy:  0.555, Loss:  0.796
# Epoch   2 Batch   47/1077 - Train Accuracy:  0.548, Loss:  0.839
# Epoch   2 Batch   47/1077 - Validation Accuracy:  0.563, Loss:  0.839
# Epoch   2 Batch  147/1077 - Train Accuracy:  0.503, Loss:  0.847
# Epoch   2 Batch  147/1077 - Validation Accuracy:  0.581, Loss:  0.847
# Epoch   2 Batch  247/1077 - Train Accuracy:  0.594, Loss:  0.759
# Epoch   2 Batch  247/1077 - Validation Accuracy:  0.592, Loss:  0.759
# Epoch   2 Batch  347/1077 - Train Accuracy:  0.590, Loss:  0.738
# Epoch   2 Batch  347/1077 - Validation Accuracy:  0.610, Loss:  0.738
# Epoch   2 Batch  447/1077 - Train Accuracy:  0.562, Loss:  0.764
# Epoch   2 Batch  447/1077 - Validation Accuracy:  0.598, Loss:  0.764
# Epoch   2 Batch  547/1077 - Train Accuracy:  0.585, Loss:  0.717
# Epoch   2 Batch  547/1077 - Validation Accuracy:  0.610, Loss:  0.717
# Epoch   2 Batch  647/1077 - Train Accuracy:  0.576, Loss:  0.717
# Epoch   2 Batch  647/1077 - Validation Accuracy:  0.612, Loss:  0.717
# Epoch   2 Batch  747/1077 - Train Accuracy:  0.589, Loss:  0.659
# Epoch   2 Batch  747/1077 - Validation Accuracy:  0.620, Loss:  0.659
# Epoch   2 Batch  847/1077 - Train Accuracy:  0.636, Loss:  0.672
# Epoch   2 Batch  847/1077 - Validation Accuracy:  0.624, Loss:  0.672
# Epoch   2 Batch  947/1077 - Train Accuracy:  0.544, Loss:  0.711
# Epoch   2 Batch  947/1077 - Validation Accuracy:  0.619, Loss:  0.711
# Epoch   2 Batch 1047/1077 - Train Accuracy:  0.584, Loss:  0.635
# Epoch   2 Batch 1047/1077 - Validation Accuracy:  0.625, Loss:  0.635
# Epoch   3 Batch   71/1077 - Train Accuracy:  0.587, Loss:  0.622
# Epoch   3 Batch   71/1077 - Validation Accuracy:  0.625, Loss:  0.622
# Epoch   3 Batch  171/1077 - Train Accuracy:  0.608, Loss:  0.568
# Epoch   3 Batch  171/1077 - Validation Accuracy:  0.630, Loss:  0.568
# Epoch   3 Batch  271/1077 - Train Accuracy:  0.611, Loss:  0.585
# Epoch   3 Batch  271/1077 - Validation Accuracy:  0.621, Loss:  0.585
# Epoch   3 Batch  371/1077 - Train Accuracy:  0.616, Loss:  0.584
# Epoch   3 Batch  371/1077 - Validation Accuracy:  0.641, Loss:  0.584
# Epoch   3 Batch  471/1077 - Train Accuracy:  0.625, Loss:  0.570
# Epoch   3 Batch  471/1077 - Validation Accuracy:  0.641, Loss:  0.570
# Epoch   3 Batch  571/1077 - Train Accuracy:  0.654, Loss:  0.528
# Epoch   3 Batch  571/1077 - Validation Accuracy:  0.643, Loss:  0.528
# Epoch   3 Batch  671/1077 - Train Accuracy:  0.583, Loss:  0.589
# Epoch   3 Batch  671/1077 - Validation Accuracy:  0.645, Loss:  0.589
# Epoch   3 Batch  771/1077 - Train Accuracy:  0.654, Loss:  0.550
# Epoch   3 Batch  771/1077 - Validation Accuracy:  0.638, Loss:  0.550
# Epoch   3 Batch  871/1077 - Train Accuracy:  0.563, Loss:  0.536
# Epoch   3 Batch  871/1077 - Validation Accuracy:  0.634, Loss:  0.536
# Epoch   3 Batch  971/1077 - Train Accuracy:  0.653, Loss:  0.499
# Epoch   3 Batch  971/1077 - Validation Accuracy:  0.628, Loss:  0.499
# Epoch   3 Batch 1071/1077 - Train Accuracy:  0.613, Loss:  0.510
# Epoch   3 Batch 1071/1077 - Validation Accuracy:  0.626, Loss:  0.510
# Epoch   4 Batch   95/1077 - Train Accuracy:  0.618, Loss:  0.514
# Epoch   4 Batch   95/1077 - Validation Accuracy:  0.650, Loss:  0.514
# Epoch   4 Batch  195/1077 - Train Accuracy:  0.607, Loss:  0.488
# Epoch   4 Batch  195/1077 - Validation Accuracy:  0.641, Loss:  0.488
# Epoch   4 Batch  295/1077 - Train Accuracy:  0.649, Loss:  0.525
# Epoch   4 Batch  295/1077 - Validation Accuracy:  0.655, Loss:  0.525
# Epoch   4 Batch  395/1077 - Train Accuracy:  0.637, Loss:  0.438
# Epoch   4 Batch  395/1077 - Validation Accuracy:  0.657, Loss:  0.438
# Epoch   4 Batch  495/1077 - Train Accuracy:  0.641, Loss:  0.451
# Epoch   4 Batch  495/1077 - Validation Accuracy:  0.672, Loss:  0.451
# Epoch   4 Batch  595/1077 - Train Accuracy:  0.618, Loss:  0.463
# Epoch   4 Batch  595/1077 - Validation Accuracy:  0.654, Loss:  0.463
# Epoch   4 Batch  695/1077 - Train Accuracy:  0.643, Loss:  0.418
# Epoch   4 Batch  695/1077 - Validation Accuracy:  0.664, Loss:  0.418
# Epoch   4 Batch  795/1077 - Train Accuracy:  0.639, Loss:  0.452
# Epoch   4 Batch  795/1077 - Validation Accuracy:  0.661, Loss:  0.452
# Epoch   4 Batch  895/1077 - Train Accuracy:  0.616, Loss:  0.433
# Epoch   4 Batch  895/1077 - Validation Accuracy:  0.668, Loss:  0.433
# Epoch   4 Batch  995/1077 - Train Accuracy:  0.688, Loss:  0.396
# Epoch   4 Batch  995/1077 - Validation Accuracy:  0.676, Loss:  0.396
# Epoch   5 Batch   19/1077 - Train Accuracy:  0.658, Loss:  0.418
# Epoch   5 Batch   19/1077 - Validation Accuracy:  0.681, Loss:  0.418
# Epoch   5 Batch  119/1077 - Train Accuracy:  0.654, Loss:  0.395
# Epoch   5 Batch  119/1077 - Validation Accuracy:  0.679, Loss:  0.395
# Epoch   5 Batch  219/1077 - Train Accuracy:  0.741, Loss:  0.387
# Epoch   5 Batch  219/1077 - Validation Accuracy:  0.674, Loss:  0.387
# Epoch   5 Batch  319/1077 - Train Accuracy:  0.698, Loss:  0.381
# Epoch   5 Batch  319/1077 - Validation Accuracy:  0.684, Loss:  0.381
# Epoch   5 Batch  419/1077 - Train Accuracy:  0.698, Loss:  0.368
# Epoch   5 Batch  419/1077 - Validation Accuracy:  0.684, Loss:  0.368
# Epoch   5 Batch  519/1077 - Train Accuracy:  0.701, Loss:  0.373
# Epoch   5 Batch  519/1077 - Validation Accuracy:  0.691, Loss:  0.373
# Epoch   5 Batch  619/1077 - Train Accuracy:  0.678, Loss:  0.364
# Epoch   5 Batch  619/1077 - Validation Accuracy:  0.685, Loss:  0.364
# Epoch   5 Batch  719/1077 - Train Accuracy:  0.685, Loss:  0.339
# Epoch   5 Batch  719/1077 - Validation Accuracy:  0.686, Loss:  0.339
# Epoch   5 Batch  819/1077 - Train Accuracy:  0.731, Loss:  0.330
# Epoch   5 Batch  819/1077 - Validation Accuracy:  0.702, Loss:  0.330
# Epoch   5 Batch  919/1077 - Train Accuracy:  0.759, Loss:  0.326
# Epoch   5 Batch  919/1077 - Validation Accuracy:  0.704, Loss:  0.326
# Epoch   5 Batch 1019/1077 - Train Accuracy:  0.710, Loss:  0.361
# Epoch   5 Batch 1019/1077 - Validation Accuracy:  0.718, Loss:  0.361
# Epoch   6 Batch   43/1077 - Train Accuracy:  0.738, Loss:  0.324
# Epoch   6 Batch   43/1077 - Validation Accuracy:  0.723, Loss:  0.324
# Epoch   6 Batch  143/1077 - Train Accuracy:  0.683, Loss:  0.319
# Epoch   6 Batch  143/1077 - Validation Accuracy:  0.713, Loss:  0.319
# Epoch   6 Batch  243/1077 - Train Accuracy:  0.700, Loss:  0.326
# Epoch   6 Batch  243/1077 - Validation Accuracy:  0.721, Loss:  0.326
# Epoch   6 Batch  343/1077 - Train Accuracy:  0.745, Loss:  0.303
# Epoch   6 Batch  343/1077 - Validation Accuracy:  0.740, Loss:  0.303
# Epoch   6 Batch  443/1077 - Train Accuracy:  0.722, Loss:  0.287
# Epoch   6 Batch  443/1077 - Validation Accuracy:  0.735, Loss:  0.287
# Epoch   6 Batch  543/1077 - Train Accuracy:  0.736, Loss:  0.291
# Epoch   6 Batch  543/1077 - Validation Accuracy:  0.751, Loss:  0.291
# Epoch   6 Batch  643/1077 - Train Accuracy:  0.766, Loss:  0.254
# Epoch   6 Batch  643/1077 - Validation Accuracy:  0.726, Loss:  0.254
# Epoch   6 Batch  743/1077 - Train Accuracy:  0.755, Loss:  0.279
# Epoch   6 Batch  743/1077 - Validation Accuracy:  0.735, Loss:  0.279
# Epoch   6 Batch  843/1077 - Train Accuracy:  0.778, Loss:  0.243
# Epoch   6 Batch  843/1077 - Validation Accuracy:  0.751, Loss:  0.243
# Epoch   6 Batch  943/1077 - Train Accuracy:  0.757, Loss:  0.263
# Epoch   6 Batch  943/1077 - Validation Accuracy:  0.760, Loss:  0.263
# Epoch   6 Batch 1043/1077 - Train Accuracy:  0.762, Loss:  0.282
# Epoch   6 Batch 1043/1077 - Validation Accuracy:  0.759, Loss:  0.282
# Epoch   7 Batch   67/1077 - Train Accuracy:  0.809, Loss:  0.246
# Epoch   7 Batch   67/1077 - Validation Accuracy:  0.767, Loss:  0.246
# Epoch   7 Batch  167/1077 - Train Accuracy:  0.804, Loss:  0.237
# Epoch   7 Batch  167/1077 - Validation Accuracy:  0.762, Loss:  0.237
# Epoch   7 Batch  267/1077 - Train Accuracy:  0.770, Loss:  0.215
# Epoch   7 Batch  267/1077 - Validation Accuracy:  0.766, Loss:  0.215
# Epoch   7 Batch  367/1077 - Train Accuracy:  0.812, Loss:  0.203
# Epoch   7 Batch  367/1077 - Validation Accuracy:  0.775, Loss:  0.203
# Epoch   7 Batch  467/1077 - Train Accuracy:  0.834, Loss:  0.230
# Epoch   7 Batch  467/1077 - Validation Accuracy:  0.788, Loss:  0.230
# Epoch   7 Batch  567/1077 - Train Accuracy:  0.759, Loss:  0.229
# Epoch   7 Batch  567/1077 - Validation Accuracy:  0.786, Loss:  0.229
# Epoch   7 Batch  667/1077 - Train Accuracy:  0.782, Loss:  0.237
# Epoch   7 Batch  667/1077 - Validation Accuracy:  0.781, Loss:  0.237
# Epoch   7 Batch  767/1077 - Train Accuracy:  0.827, Loss:  0.205
# Epoch   7 Batch  767/1077 - Validation Accuracy:  0.787, Loss:  0.205
# Epoch   7 Batch  867/1077 - Train Accuracy:  0.754, Loss:  0.251
# Epoch   7 Batch  867/1077 - Validation Accuracy:  0.778, Loss:  0.251
# Epoch   7 Batch  967/1077 - Train Accuracy:  0.799, Loss:  0.184
# Epoch   7 Batch  967/1077 - Validation Accuracy:  0.783, Loss:  0.184
# Epoch   7 Batch 1067/1077 - Train Accuracy:  0.839, Loss:  0.215
# Epoch   7 Batch 1067/1077 - Validation Accuracy:  0.802, Loss:  0.215
# Epoch   8 Batch   91/1077 - Train Accuracy:  0.843, Loss:  0.170
# Epoch   8 Batch   91/1077 - Validation Accuracy:  0.808, Loss:  0.170
# Epoch   8 Batch  191/1077 - Train Accuracy:  0.797, Loss:  0.171
# Epoch   8 Batch  191/1077 - Validation Accuracy:  0.796, Loss:  0.171
# Epoch   8 Batch  291/1077 - Train Accuracy:  0.777, Loss:  0.203
# Epoch   8 Batch  291/1077 - Validation Accuracy:  0.805, Loss:  0.203
# Epoch   8 Batch  391/1077 - Train Accuracy:  0.826, Loss:  0.180
# Epoch   8 Batch  391/1077 - Validation Accuracy:  0.801, Loss:  0.180
# Epoch   8 Batch  491/1077 - Train Accuracy:  0.819, Loss:  0.177
# Epoch   8 Batch  491/1077 - Validation Accuracy:  0.825, Loss:  0.177
# Epoch   8 Batch  591/1077 - Train Accuracy:  0.832, Loss:  0.160
# Epoch   8 Batch  591/1077 - Validation Accuracy:  0.808, Loss:  0.160
# Epoch   8 Batch  691/1077 - Train Accuracy:  0.814, Loss:  0.203
# Epoch   8 Batch  691/1077 - Validation Accuracy:  0.819, Loss:  0.203
# Epoch   8 Batch  791/1077 - Train Accuracy:  0.832, Loss:  0.180
# Epoch   8 Batch  791/1077 - Validation Accuracy:  0.813, Loss:  0.180
# Epoch   8 Batch  891/1077 - Train Accuracy:  0.869, Loss:  0.166
# Epoch   8 Batch  891/1077 - Validation Accuracy:  0.824, Loss:  0.166
# Epoch   8 Batch  991/1077 - Train Accuracy:  0.847, Loss:  0.151
# Epoch   8 Batch  991/1077 - Validation Accuracy:  0.841, Loss:  0.151
# Epoch   9 Batch   15/1077 - Train Accuracy:  0.858, Loss:  0.157
# Epoch   9 Batch   15/1077 - Validation Accuracy:  0.810, Loss:  0.157
# Epoch   9 Batch  115/1077 - Train Accuracy:  0.851, Loss:  0.156
# Epoch   9 Batch  115/1077 - Validation Accuracy:  0.850, Loss:  0.156
# Epoch   9 Batch  215/1077 - Train Accuracy:  0.820, Loss:  0.162
# Epoch   9 Batch  215/1077 - Validation Accuracy:  0.846, Loss:  0.162
# Epoch   9 Batch  315/1077 - Train Accuracy:  0.890, Loss:  0.135
# Epoch   9 Batch  315/1077 - Validation Accuracy:  0.863, Loss:  0.135
# Epoch   9 Batch  415/1077 - Train Accuracy:  0.852, Loss:  0.150
# Epoch   9 Batch  415/1077 - Validation Accuracy:  0.837, Loss:  0.150
# Epoch   9 Batch  515/1077 - Train Accuracy:  0.840, Loss:  0.156
# Epoch   9 Batch  515/1077 - Validation Accuracy:  0.841, Loss:  0.156
# Epoch   9 Batch  615/1077 - Train Accuracy:  0.862, Loss:  0.131
# Epoch   9 Batch  615/1077 - Validation Accuracy:  0.860, Loss:  0.131
# Epoch   9 Batch  715/1077 - Train Accuracy:  0.844, Loss:  0.151
# Epoch   9 Batch  715/1077 - Validation Accuracy:  0.841, Loss:  0.151
# Epoch   9 Batch  815/1077 - Train Accuracy:  0.883, Loss:  0.132
# Epoch   9 Batch  815/1077 - Validation Accuracy:  0.847, Loss:  0.132
# Epoch   9 Batch  915/1077 - Train Accuracy:  0.844, Loss:  0.137
# Epoch   9 Batch  915/1077 - Validation Accuracy:  0.854, Loss:  0.137
# Epoch   9 Batch 1015/1077 - Train Accuracy:  0.876, Loss:  0.143
# Epoch   9 Batch 1015/1077 - Validation Accuracy:  0.853, Loss:  0.143
# Epoch  10 Batch   39/1077 - Train Accuracy:  0.877, Loss:  0.137
# Epoch  10 Batch   39/1077 - Validation Accuracy:  0.863, Loss:  0.137
# Epoch  10 Batch  139/1077 - Train Accuracy:  0.878, Loss:  0.131
# Epoch  10 Batch  139/1077 - Validation Accuracy:  0.844, Loss:  0.131
# Epoch  10 Batch  239/1077 - Train Accuracy:  0.875, Loss:  0.098
# Epoch  10 Batch  239/1077 - Validation Accuracy:  0.862, Loss:  0.098
# Epoch  10 Batch  339/1077 - Train Accuracy:  0.882, Loss:  0.107
# Epoch  10 Batch  339/1077 - Validation Accuracy:  0.857, Loss:  0.107
# Epoch  10 Batch  439/1077 - Train Accuracy:  0.851, Loss:  0.128
# Epoch  10 Batch  439/1077 - Validation Accuracy:  0.849, Loss:  0.128
# Epoch  10 Batch  539/1077 - Train Accuracy:  0.860, Loss:  0.122
# Epoch  10 Batch  539/1077 - Validation Accuracy:  0.852, Loss:  0.122
# Epoch  10 Batch  639/1077 - Train Accuracy:  0.889, Loss:  0.113
# Epoch  10 Batch  639/1077 - Validation Accuracy:  0.868, Loss:  0.113
# Epoch  10 Batch  739/1077 - Train Accuracy:  0.905, Loss:  0.100
# Epoch  10 Batch  739/1077 - Validation Accuracy:  0.880, Loss:  0.100
# Epoch  10 Batch  839/1077 - Train Accuracy:  0.877, Loss:  0.098
# Epoch  10 Batch  839/1077 - Validation Accuracy:  0.869, Loss:  0.098
# Epoch  10 Batch  939/1077 - Train Accuracy:  0.888, Loss:  0.118
# Epoch  10 Batch  939/1077 - Validation Accuracy:  0.878, Loss:  0.118
# Epoch  10 Batch 1039/1077 - Train Accuracy:  0.885, Loss:  0.115
# Epoch  10 Batch 1039/1077 - Validation Accuracy:  0.881, Loss:  0.115
# Epoch  11 Batch   63/1077 - Train Accuracy:  0.916, Loss:  0.087
# Epoch  11 Batch   63/1077 - Validation Accuracy:  0.862, Loss:  0.087
# Epoch  11 Batch  163/1077 - Train Accuracy:  0.885, Loss:  0.115
# Epoch  11 Batch  163/1077 - Validation Accuracy:  0.862, Loss:  0.115
# Epoch  11 Batch  263/1077 - Train Accuracy:  0.934, Loss:  0.082
# Epoch  11 Batch  263/1077 - Validation Accuracy:  0.876, Loss:  0.082
# Epoch  11 Batch  363/1077 - Train Accuracy:  0.863, Loss:  0.102
# Epoch  11 Batch  363/1077 - Validation Accuracy:  0.869, Loss:  0.102
# Epoch  11 Batch  463/1077 - Train Accuracy:  0.848, Loss:  0.091
# Epoch  11 Batch  463/1077 - Validation Accuracy:  0.863, Loss:  0.091
# Epoch  11 Batch  563/1077 - Train Accuracy:  0.871, Loss:  0.106
# Epoch  11 Batch  563/1077 - Validation Accuracy:  0.858, Loss:  0.106
# Epoch  11 Batch  663/1077 - Train Accuracy:  0.875, Loss:  0.081
# Epoch  11 Batch  663/1077 - Validation Accuracy:  0.870, Loss:  0.081
# Epoch  11 Batch  763/1077 - Train Accuracy:  0.905, Loss:  0.081
# Epoch  11 Batch  763/1077 - Validation Accuracy:  0.872, Loss:  0.081
# Epoch  11 Batch  863/1077 - Train Accuracy:  0.918, Loss:  0.070
# Epoch  11 Batch  863/1077 - Validation Accuracy:  0.874, Loss:  0.070
# Epoch  11 Batch  963/1077 - Train Accuracy:  0.920, Loss:  0.100
# Epoch  11 Batch  963/1077 - Validation Accuracy:  0.874, Loss:  0.100
# Epoch  11 Batch 1063/1077 - Train Accuracy:  0.872, Loss:  0.090
# Epoch  11 Batch 1063/1077 - Validation Accuracy:  0.881, Loss:  0.090
# Epoch  12 Batch   87/1077 - Train Accuracy:  0.889, Loss:  0.113
# Epoch  12 Batch   87/1077 - Validation Accuracy:  0.880, Loss:  0.113
# Epoch  12 Batch  187/1077 - Train Accuracy:  0.899, Loss:  0.071
# Epoch  12 Batch  187/1077 - Validation Accuracy:  0.874, Loss:  0.071
# Epoch  12 Batch  287/1077 - Train Accuracy:  0.904, Loss:  0.080
# Epoch  12 Batch  287/1077 - Validation Accuracy:  0.882, Loss:  0.080
# Epoch  12 Batch  387/1077 - Train Accuracy:  0.891, Loss:  0.080
# Epoch  12 Batch  387/1077 - Validation Accuracy:  0.886, Loss:  0.080
# Epoch  12 Batch  487/1077 - Train Accuracy:  0.927, Loss:  0.076
# Epoch  12 Batch  487/1077 - Validation Accuracy:  0.882, Loss:  0.076
# Epoch  12 Batch  587/1077 - Train Accuracy:  0.895, Loss:  0.078
# Epoch  12 Batch  587/1077 - Validation Accuracy:  0.883, Loss:  0.078
# Epoch  12 Batch  687/1077 - Train Accuracy:  0.912, Loss:  0.078
# Epoch  12 Batch  687/1077 - Validation Accuracy:  0.868, Loss:  0.078
# Epoch  12 Batch  787/1077 - Train Accuracy:  0.911, Loss:  0.065
# Epoch  12 Batch  787/1077 - Validation Accuracy:  0.886, Loss:  0.065
# Epoch  12 Batch  887/1077 - Train Accuracy:  0.873, Loss:  0.095
# Epoch  12 Batch  887/1077 - Validation Accuracy:  0.882, Loss:  0.095
# Epoch  12 Batch  987/1077 - Train Accuracy:  0.882, Loss:  0.071
# Epoch  12 Batch  987/1077 - Validation Accuracy:  0.898, Loss:  0.071
# Epoch  13 Batch   11/1077 - Train Accuracy:  0.876, Loss:  0.081
# Epoch  13 Batch   11/1077 - Validation Accuracy:  0.879, Loss:  0.081
# Epoch  13 Batch  111/1077 - Train Accuracy:  0.898, Loss:  0.067
# Epoch  13 Batch  111/1077 - Validation Accuracy:  0.880, Loss:  0.067
# Epoch  13 Batch  211/1077 - Train Accuracy:  0.892, Loss:  0.065
# Epoch  13 Batch  211/1077 - Validation Accuracy:  0.877, Loss:  0.065
# Epoch  13 Batch  311/1077 - Train Accuracy:  0.895, Loss:  0.059
# Epoch  13 Batch  311/1077 - Validation Accuracy:  0.876, Loss:  0.059
# Epoch  13 Batch  411/1077 - Train Accuracy:  0.913, Loss:  0.066
# Epoch  13 Batch  411/1077 - Validation Accuracy:  0.887, Loss:  0.066
# Epoch  13 Batch  511/1077 - Train Accuracy:  0.872, Loss:  0.068
# Epoch  13 Batch  511/1077 - Validation Accuracy:  0.880, Loss:  0.068
# Epoch  13 Batch  611/1077 - Train Accuracy:  0.891, Loss:  0.080
# Epoch  13 Batch  611/1077 - Validation Accuracy:  0.891, Loss:  0.080
# Epoch  13 Batch  711/1077 - Train Accuracy:  0.894, Loss:  0.076
# Epoch  13 Batch  711/1077 - Validation Accuracy:  0.901, Loss:  0.076
# Epoch  13 Batch  811/1077 - Train Accuracy:  0.900, Loss:  0.064
# Epoch  13 Batch  811/1077 - Validation Accuracy:  0.884, Loss:  0.064
# Epoch  13 Batch  911/1077 - Train Accuracy:  0.885, Loss:  0.080
# Epoch  13 Batch  911/1077 - Validation Accuracy:  0.867, Loss:  0.080
# Epoch  13 Batch 1011/1077 - Train Accuracy:  0.900, Loss:  0.056
# Epoch  13 Batch 1011/1077 - Validation Accuracy:  0.901, Loss:  0.056
# Epoch  14 Batch   35/1077 - Train Accuracy:  0.923, Loss:  0.060
# Epoch  14 Batch   35/1077 - Validation Accuracy:  0.903, Loss:  0.060
# Epoch  14 Batch  135/1077 - Train Accuracy:  0.912, Loss:  0.066
# Epoch  14 Batch  135/1077 - Validation Accuracy:  0.900, Loss:  0.066
# Epoch  14 Batch  235/1077 - Train Accuracy:  0.888, Loss:  0.070
# Epoch  14 Batch  235/1077 - Validation Accuracy:  0.904, Loss:  0.070
# Epoch  14 Batch  335/1077 - Train Accuracy:  0.910, Loss:  0.055
# Epoch  14 Batch  335/1077 - Validation Accuracy:  0.881, Loss:  0.055
# Epoch  14 Batch  435/1077 - Train Accuracy:  0.924, Loss:  0.070
# Epoch  14 Batch  435/1077 - Validation Accuracy:  0.905, Loss:  0.070
# Epoch  14 Batch  535/1077 - Train Accuracy:  0.896, Loss:  0.060
# Epoch  14 Batch  535/1077 - Validation Accuracy:  0.887, Loss:  0.060
# Epoch  14 Batch  635/1077 - Train Accuracy:  0.907, Loss:  0.071
# Epoch  14 Batch  635/1077 - Validation Accuracy:  0.909, Loss:  0.071
# Epoch  14 Batch  735/1077 - Train Accuracy:  0.913, Loss:  0.058
# Epoch  14 Batch  735/1077 - Validation Accuracy:  0.872, Loss:  0.058
# Epoch  14 Batch  835/1077 - Train Accuracy:  0.920, Loss:  0.058
# Epoch  14 Batch  835/1077 - Validation Accuracy:  0.914, Loss:  0.058
# Epoch  14 Batch  935/1077 - Train Accuracy:  0.916, Loss:  0.056
# Epoch  14 Batch  935/1077 - Validation Accuracy:  0.892, Loss:  0.056
# Epoch  14 Batch 1035/1077 - Train Accuracy:  0.944, Loss:  0.044
# Epoch  14 Batch 1035/1077 - Validation Accuracy:  0.882, Loss:  0.044
# Epoch  15 Batch   59/1077 - Train Accuracy:  0.904, Loss:  0.060
# Epoch  15 Batch   59/1077 - Validation Accuracy:  0.896, Loss:  0.060
# Epoch  15 Batch  159/1077 - Train Accuracy:  0.902, Loss:  0.045
# Epoch  15 Batch  159/1077 - Validation Accuracy:  0.899, Loss:  0.045
# Epoch  15 Batch  259/1077 - Train Accuracy:  0.909, Loss:  0.051
# Epoch  15 Batch  259/1077 - Validation Accuracy:  0.895, Loss:  0.051
# Epoch  15 Batch  359/1077 - Train Accuracy:  0.915, Loss:  0.055
# Epoch  15 Batch  359/1077 - Validation Accuracy:  0.908, Loss:  0.055
# Epoch  15 Batch  459/1077 - Train Accuracy:  0.913, Loss:  0.054
# Epoch  15 Batch  459/1077 - Validation Accuracy:  0.900, Loss:  0.054
# Epoch  15 Batch  559/1077 - Train Accuracy:  0.905, Loss:  0.050
# Epoch  15 Batch  559/1077 - Validation Accuracy:  0.901, Loss:  0.050
# Epoch  15 Batch  659/1077 - Train Accuracy:  0.919, Loss:  0.057
# Epoch  15 Batch  659/1077 - Validation Accuracy:  0.902, Loss:  0.057
# Epoch  15 Batch  759/1077 - Train Accuracy:  0.895, Loss:  0.051
# Epoch  15 Batch  759/1077 - Validation Accuracy:  0.902, Loss:  0.051
# Epoch  15 Batch  859/1077 - Train Accuracy:  0.927, Loss:  0.057
# Epoch  15 Batch  859/1077 - Validation Accuracy:  0.917, Loss:  0.057
# Epoch  15 Batch  959/1077 - Train Accuracy:  0.911, Loss:  0.068
# Epoch  15 Batch  959/1077 - Validation Accuracy:  0.884, Loss:  0.068
# Epoch  15 Batch 1059/1077 - Train Accuracy:  0.878, Loss:  0.066
# Epoch  15 Batch 1059/1077 - Validation Accuracy:  0.913, Loss:  0.066
# Epoch  16 Batch   83/1077 - Train Accuracy:  0.945, Loss:  0.048
# Epoch  16 Batch   83/1077 - Validation Accuracy:  0.887, Loss:  0.048
# Epoch  16 Batch  183/1077 - Train Accuracy:  0.932, Loss:  0.053
# Epoch  16 Batch  183/1077 - Validation Accuracy:  0.913, Loss:  0.053
# Epoch  16 Batch  283/1077 - Train Accuracy:  0.938, Loss:  0.053
# Epoch  16 Batch  283/1077 - Validation Accuracy:  0.897, Loss:  0.053
# Epoch  16 Batch  383/1077 - Train Accuracy:  0.935, Loss:  0.049
# Epoch  16 Batch  383/1077 - Validation Accuracy:  0.907, Loss:  0.049
# Epoch  16 Batch  483/1077 - Train Accuracy:  0.884, Loss:  0.077
# Epoch  16 Batch  483/1077 - Validation Accuracy:  0.914, Loss:  0.077
# Epoch  16 Batch  583/1077 - Train Accuracy:  0.919, Loss:  0.057
# Epoch  16 Batch  583/1077 - Validation Accuracy:  0.908, Loss:  0.057
# Epoch  16 Batch  683/1077 - Train Accuracy:  0.910, Loss:  0.044
# Epoch  16 Batch  683/1077 - Validation Accuracy:  0.922, Loss:  0.044
# Epoch  16 Batch  783/1077 - Train Accuracy:  0.899, Loss:  0.057
# Epoch  16 Batch  783/1077 - Validation Accuracy:  0.919, Loss:  0.057
# Epoch  16 Batch  883/1077 - Train Accuracy:  0.908, Loss:  0.067
# Epoch  16 Batch  883/1077 - Validation Accuracy:  0.915, Loss:  0.067
# Epoch  16 Batch  983/1077 - Train Accuracy:  0.908, Loss:  0.047
# Epoch  16 Batch  983/1077 - Validation Accuracy:  0.907, Loss:  0.047
# Epoch  17 Batch    7/1077 - Train Accuracy:  0.943, Loss:  0.038
# Epoch  17 Batch    7/1077 - Validation Accuracy:  0.905, Loss:  0.038
# Epoch  17 Batch  107/1077 - Train Accuracy:  0.893, Loss:  0.050
# Epoch  17 Batch  107/1077 - Validation Accuracy:  0.902, Loss:  0.050
# Epoch  17 Batch  207/1077 - Train Accuracy:  0.924, Loss:  0.040
# Epoch  17 Batch  207/1077 - Validation Accuracy:  0.898, Loss:  0.040
# Epoch  17 Batch  307/1077 - Train Accuracy:  0.915, Loss:  0.042
# Epoch  17 Batch  307/1077 - Validation Accuracy:  0.920, Loss:  0.042
# Epoch  17 Batch  407/1077 - Train Accuracy:  0.900, Loss:  0.049
# Epoch  17 Batch  407/1077 - Validation Accuracy:  0.908, Loss:  0.049
# Epoch  17 Batch  507/1077 - Train Accuracy:  0.868, Loss:  0.049
# Epoch  17 Batch  507/1077 - Validation Accuracy:  0.919, Loss:  0.049
# Epoch  17 Batch  607/1077 - Train Accuracy:  0.924, Loss:  0.047
# Epoch  17 Batch  607/1077 - Validation Accuracy:  0.914, Loss:  0.047
# Epoch  17 Batch  707/1077 - Train Accuracy:  0.922, Loss:  0.045
# Epoch  17 Batch  707/1077 - Validation Accuracy:  0.921, Loss:  0.045
# Epoch  17 Batch  807/1077 - Train Accuracy:  0.949, Loss:  0.034
# Epoch  17 Batch  807/1077 - Validation Accuracy:  0.912, Loss:  0.034
# Epoch  17 Batch  907/1077 - Train Accuracy:  0.941, Loss:  0.041
# Epoch  17 Batch  907/1077 - Validation Accuracy:  0.917, Loss:  0.041
# Epoch  17 Batch 1007/1077 - Train Accuracy:  0.929, Loss:  0.037
# Epoch  17 Batch 1007/1077 - Validation Accuracy:  0.911, Loss:  0.037
# Epoch  18 Batch   31/1077 - Train Accuracy:  0.930, Loss:  0.044
# Epoch  18 Batch   31/1077 - Validation Accuracy:  0.913, Loss:  0.044
# Epoch  18 Batch  131/1077 - Train Accuracy:  0.889, Loss:  0.051
# Epoch  18 Batch  131/1077 - Validation Accuracy:  0.911, Loss:  0.051
# Epoch  18 Batch  231/1077 - Train Accuracy:  0.928, Loss:  0.045
# Epoch  18 Batch  231/1077 - Validation Accuracy:  0.918, Loss:  0.045
# Epoch  18 Batch  331/1077 - Train Accuracy:  0.913, Loss:  0.046
# Epoch  18 Batch  331/1077 - Validation Accuracy:  0.900, Loss:  0.046
# Epoch  18 Batch  431/1077 - Train Accuracy:  0.904, Loss:  0.039
# Epoch  18 Batch  431/1077 - Validation Accuracy:  0.918, Loss:  0.039
# Epoch  18 Batch  531/1077 - Train Accuracy:  0.917, Loss:  0.045
# Epoch  18 Batch  531/1077 - Validation Accuracy:  0.918, Loss:  0.045
# Epoch  18 Batch  631/1077 - Train Accuracy:  0.910, Loss:  0.047
# Epoch  18 Batch  631/1077 - Validation Accuracy:  0.919, Loss:  0.047
# Epoch  18 Batch  731/1077 - Train Accuracy:  0.914, Loss:  0.045
# Epoch  18 Batch  731/1077 - Validation Accuracy:  0.913, Loss:  0.045
# Epoch  18 Batch  831/1077 - Train Accuracy:  0.901, Loss:  0.044
# Epoch  18 Batch  831/1077 - Validation Accuracy:  0.906, Loss:  0.044
# Epoch  18 Batch  931/1077 - Train Accuracy:  0.934, Loss:  0.038
# Epoch  18 Batch  931/1077 - Validation Accuracy:  0.920, Loss:  0.038
# Epoch  18 Batch 1031/1077 - Train Accuracy:  0.933, Loss:  0.042
# Epoch  18 Batch 1031/1077 - Validation Accuracy:  0.904, Loss:  0.042
# Epoch  19 Batch   55/1077 - Train Accuracy:  0.936, Loss:  0.036
# Epoch  19 Batch   55/1077 - Validation Accuracy:  0.920, Loss:  0.036
# Epoch  19 Batch  155/1077 - Train Accuracy:  0.957, Loss:  0.036
# Epoch  19 Batch  155/1077 - Validation Accuracy:  0.920, Loss:  0.036
# Epoch  19 Batch  255/1077 - Train Accuracy:  0.927, Loss:  0.037
# Epoch  19 Batch  255/1077 - Validation Accuracy:  0.909, Loss:  0.037
# Epoch  19 Batch  355/1077 - Train Accuracy:  0.923, Loss:  0.040
# Epoch  19 Batch  355/1077 - Validation Accuracy:  0.930, Loss:  0.040
# Epoch  19 Batch  455/1077 - Train Accuracy:  0.933, Loss:  0.038
# Epoch  19 Batch  455/1077 - Validation Accuracy:  0.912, Loss:  0.038
# Epoch  19 Batch  555/1077 - Train Accuracy:  0.914, Loss:  0.035
# Epoch  19 Batch  555/1077 - Validation Accuracy:  0.913, Loss:  0.035
# Epoch  19 Batch  655/1077 - Train Accuracy:  0.918, Loss:  0.048
# Epoch  19 Batch  655/1077 - Validation Accuracy:  0.919, Loss:  0.048
# Epoch  19 Batch  755/1077 - Train Accuracy:  0.930, Loss:  0.050
# Epoch  19 Batch  755/1077 - Validation Accuracy:  0.908, Loss:  0.050
# Epoch  19 Batch  855/1077 - Train Accuracy:  0.896, Loss:  0.042
# Epoch  19 Batch  855/1077 - Validation Accuracy:  0.908, Loss:  0.042
# Epoch  19 Batch  955/1077 - Train Accuracy:  0.913, Loss:  0.045
# Epoch  19 Batch  955/1077 - Validation Accuracy:  0.934, Loss:  0.045
# Epoch  19 Batch 1055/1077 - Train Accuracy:  0.935, Loss:  0.050
# Epoch  19 Batch 1055/1077 - Validation Accuracy:  0.916, Loss:  0.050
# Epoch  20 Batch   79/1077 - Train Accuracy:  0.962, Loss:  0.031
# Epoch  20 Batch   79/1077 - Validation Accuracy:  0.912, Loss:  0.031
# Epoch  20 Batch  179/1077 - Train Accuracy:  0.933, Loss:  0.038
# Epoch  20 Batch  179/1077 - Validation Accuracy:  0.913, Loss:  0.038
# Epoch  20 Batch  279/1077 - Train Accuracy:  0.933, Loss:  0.049
# Epoch  20 Batch  279/1077 - Validation Accuracy:  0.923, Loss:  0.049
# Epoch  20 Batch  379/1077 - Train Accuracy:  0.931, Loss:  0.050
# Epoch  20 Batch  379/1077 - Validation Accuracy:  0.918, Loss:  0.050
# Epoch  20 Batch  479/1077 - Train Accuracy:  0.914, Loss:  0.038
# Epoch  20 Batch  479/1077 - Validation Accuracy:  0.923, Loss:  0.038
# Epoch  20 Batch  579/1077 - Train Accuracy:  0.902, Loss:  0.035
# Epoch  20 Batch  579/1077 - Validation Accuracy:  0.928, Loss:  0.035
# Epoch  20 Batch  679/1077 - Train Accuracy:  0.919, Loss:  0.037
# Epoch  20 Batch  679/1077 - Validation Accuracy:  0.928, Loss:  0.037
# Epoch  20 Batch  779/1077 - Train Accuracy:  0.937, Loss:  0.036
# Epoch  20 Batch  779/1077 - Validation Accuracy:  0.923, Loss:  0.036
# Epoch  20 Batch  879/1077 - Train Accuracy:  0.944, Loss:  0.029
# Epoch  20 Batch  879/1077 - Validation Accuracy:  0.929, Loss:  0.029
# Epoch  20 Batch  979/1077 - Train Accuracy:  0.908, Loss:  0.044
# Epoch  20 Batch  979/1077 - Validation Accuracy:  0.918, Loss:  0.044
# Epoch  21 Batch    3/1077 - Train Accuracy:  0.945, Loss:  0.048
# Epoch  21 Batch    3/1077 - Validation Accuracy:  0.918, Loss:  0.048
# Epoch  21 Batch  103/1077 - Train Accuracy:  0.920, Loss:  0.048
# Epoch  21 Batch  103/1077 - Validation Accuracy:  0.929, Loss:  0.048
# Epoch  21 Batch  203/1077 - Train Accuracy:  0.905, Loss:  0.035
# Epoch  21 Batch  203/1077 - Validation Accuracy:  0.916, Loss:  0.035
# Epoch  21 Batch  303/1077 - Train Accuracy:  0.936, Loss:  0.040
# Epoch  21 Batch  303/1077 - Validation Accuracy:  0.926, Loss:  0.040
# Epoch  21 Batch  403/1077 - Train Accuracy:  0.917, Loss:  0.046
# Epoch  21 Batch  403/1077 - Validation Accuracy:  0.920, Loss:  0.046
# Epoch  21 Batch  503/1077 - Train Accuracy:  0.939, Loss:  0.031
# Epoch  21 Batch  503/1077 - Validation Accuracy:  0.923, Loss:  0.031
# Epoch  21 Batch  603/1077 - Train Accuracy:  0.923, Loss:  0.035
# Epoch  21 Batch  603/1077 - Validation Accuracy:  0.925, Loss:  0.035
# Epoch  21 Batch  703/1077 - Train Accuracy:  0.925, Loss:  0.035
# Epoch  21 Batch  703/1077 - Validation Accuracy:  0.921, Loss:  0.035
# Epoch  21 Batch  803/1077 - Train Accuracy:  0.939, Loss:  0.040
# Epoch  21 Batch  803/1077 - Validation Accuracy:  0.920, Loss:  0.040
# Epoch  21 Batch  903/1077 - Train Accuracy:  0.926, Loss:  0.033
# Epoch  21 Batch  903/1077 - Validation Accuracy:  0.930, Loss:  0.033
# Epoch  21 Batch 1003/1077 - Train Accuracy:  0.938, Loss:  0.033
# Epoch  21 Batch 1003/1077 - Validation Accuracy:  0.928, Loss:  0.033
# Epoch  22 Batch   27/1077 - Train Accuracy:  0.940, Loss:  0.028
# Epoch  22 Batch   27/1077 - Validation Accuracy:  0.936, Loss:  0.028
# Epoch  22 Batch  127/1077 - Train Accuracy:  0.930, Loss:  0.031
# Epoch  22 Batch  127/1077 - Validation Accuracy:  0.931, Loss:  0.031
# Epoch  22 Batch  227/1077 - Train Accuracy:  0.888, Loss:  0.047
# Epoch  22 Batch  227/1077 - Validation Accuracy:  0.933, Loss:  0.047
# Epoch  22 Batch  327/1077 - Train Accuracy:  0.931, Loss:  0.043
# Epoch  22 Batch  327/1077 - Validation Accuracy:  0.932, Loss:  0.043
# Epoch  22 Batch  427/1077 - Train Accuracy:  0.924, Loss:  0.034
# Epoch  22 Batch  427/1077 - Validation Accuracy:  0.915, Loss:  0.034
# Epoch  22 Batch  527/1077 - Train Accuracy:  0.910, Loss:  0.038
# Epoch  22 Batch  527/1077 - Validation Accuracy:  0.924, Loss:  0.038
# Epoch  22 Batch  627/1077 - Train Accuracy:  0.921, Loss:  0.031
# Epoch  22 Batch  627/1077 - Validation Accuracy:  0.926, Loss:  0.031
# Epoch  22 Batch  727/1077 - Train Accuracy:  0.938, Loss:  0.032
# Epoch  22 Batch  727/1077 - Validation Accuracy:  0.925, Loss:  0.032
# Epoch  22 Batch  827/1077 - Train Accuracy:  0.936, Loss:  0.030
# Epoch  22 Batch  827/1077 - Validation Accuracy:  0.932, Loss:  0.030
# Epoch  22 Batch  927/1077 - Train Accuracy:  0.912, Loss:  0.041
# Epoch  22 Batch  927/1077 - Validation Accuracy:  0.936, Loss:  0.041
# Epoch  22 Batch 1027/1077 - Train Accuracy:  0.918, Loss:  0.029
# Epoch  22 Batch 1027/1077 - Validation Accuracy:  0.930, Loss:  0.029
# Epoch  23 Batch   51/1077 - Train Accuracy:  0.928, Loss:  0.034
# Epoch  23 Batch   51/1077 - Validation Accuracy:  0.939, Loss:  0.034
# Epoch  23 Batch  151/1077 - Train Accuracy:  0.926, Loss:  0.033
# Epoch  23 Batch  151/1077 - Validation Accuracy:  0.923, Loss:  0.033
# Epoch  23 Batch  251/1077 - Train Accuracy:  0.924, Loss:  0.037
# Epoch  23 Batch  251/1077 - Validation Accuracy:  0.926, Loss:  0.037
# Epoch  23 Batch  351/1077 - Train Accuracy:  0.939, Loss:  0.036
# Epoch  23 Batch  351/1077 - Validation Accuracy:  0.930, Loss:  0.036
# Epoch  23 Batch  451/1077 - Train Accuracy:  0.950, Loss:  0.027
# Epoch  23 Batch  451/1077 - Validation Accuracy:  0.934, Loss:  0.027
# Epoch  23 Batch  551/1077 - Train Accuracy:  0.939, Loss:  0.034
# Epoch  23 Batch  551/1077 - Validation Accuracy:  0.930, Loss:  0.034
# Epoch  23 Batch  651/1077 - Train Accuracy:  0.936, Loss:  0.032
# Epoch  23 Batch  651/1077 - Validation Accuracy:  0.931, Loss:  0.032
# Epoch  23 Batch  751/1077 - Train Accuracy:  0.956, Loss:  0.031
# Epoch  23 Batch  751/1077 - Validation Accuracy:  0.928, Loss:  0.031
# Epoch  23 Batch  851/1077 - Train Accuracy:  0.944, Loss:  0.045
# Epoch  23 Batch  851/1077 - Validation Accuracy:  0.929, Loss:  0.045
# Epoch  23 Batch  951/1077 - Train Accuracy:  0.924, Loss:  0.035
# Epoch  23 Batch  951/1077 - Validation Accuracy:  0.945, Loss:  0.035
# Epoch  23 Batch 1051/1077 - Train Accuracy:  0.922, Loss:  0.038
# Epoch  23 Batch 1051/1077 - Validation Accuracy:  0.931, Loss:  0.038
# Epoch  24 Batch   75/1077 - Train Accuracy:  0.940, Loss:  0.045
# Epoch  24 Batch   75/1077 - Validation Accuracy:  0.947, Loss:  0.045
# Epoch  24 Batch  175/1077 - Train Accuracy:  0.941, Loss:  0.035
# Epoch  24 Batch  175/1077 - Validation Accuracy:  0.932, Loss:  0.035
# Epoch  24 Batch  275/1077 - Train Accuracy:  0.940, Loss:  0.030
# Epoch  24 Batch  275/1077 - Validation Accuracy:  0.927, Loss:  0.030
# Epoch  24 Batch  375/1077 - Train Accuracy:  0.947, Loss:  0.026
# Epoch  24 Batch  375/1077 - Validation Accuracy:  0.929, Loss:  0.026
# Epoch  24 Batch  475/1077 - Train Accuracy:  0.930, Loss:  0.028
# Epoch  24 Batch  475/1077 - Validation Accuracy:  0.936, Loss:  0.028
# Epoch  24 Batch  575/1077 - Train Accuracy:  0.949, Loss:  0.028
# Epoch  24 Batch  575/1077 - Validation Accuracy:  0.929, Loss:  0.028
# Epoch  24 Batch  675/1077 - Train Accuracy:  0.943, Loss:  0.035
# Epoch  24 Batch  675/1077 - Validation Accuracy:  0.932, Loss:  0.035
# Epoch  24 Batch  775/1077 - Train Accuracy:  0.928, Loss:  0.027
# Epoch  24 Batch  775/1077 - Validation Accuracy:  0.930, Loss:  0.027
# Epoch  24 Batch  875/1077 - Train Accuracy:  0.948, Loss:  0.033
# Epoch  24 Batch  875/1077 - Validation Accuracy:  0.937, Loss:  0.033
# Epoch  24 Batch  975/1077 - Train Accuracy:  0.957, Loss:  0.032
# Epoch  24 Batch  975/1077 - Validation Accuracy:  0.933, Loss:  0.032
# Epoch  24 Batch 1075/1077 - Train Accuracy:  0.929, Loss:  0.031
# Epoch  24 Batch 1075/1077 - Validation Accuracy:  0.924, Loss:  0.031
# Epoch  25 Batch   99/1077 - Train Accuracy:  0.963, Loss:  0.027
# Epoch  25 Batch   99/1077 - Validation Accuracy:  0.934, Loss:  0.027
# Epoch  25 Batch  199/1077 - Train Accuracy:  0.957, Loss:  0.025
# Epoch  25 Batch  199/1077 - Validation Accuracy:  0.934, Loss:  0.025
# Epoch  25 Batch  299/1077 - Train Accuracy:  0.940, Loss:  0.036
# Epoch  25 Batch  299/1077 - Validation Accuracy:  0.940, Loss:  0.036
# Epoch  25 Batch  399/1077 - Train Accuracy:  0.920, Loss:  0.032
# Epoch  25 Batch  399/1077 - Validation Accuracy:  0.925, Loss:  0.032
# Epoch  25 Batch  499/1077 - Train Accuracy:  0.927, Loss:  0.031
# Epoch  25 Batch  499/1077 - Validation Accuracy:  0.933, Loss:  0.031
# Epoch  25 Batch  599/1077 - Train Accuracy:  0.918, Loss:  0.047
# Epoch  25 Batch  599/1077 - Validation Accuracy:  0.925, Loss:  0.047
# Epoch  25 Batch  699/1077 - Train Accuracy:  0.945, Loss:  0.027
# Epoch  25 Batch  699/1077 - Validation Accuracy:  0.931, Loss:  0.027
# Epoch  25 Batch  799/1077 - Train Accuracy:  0.940, Loss:  0.036
# Epoch  25 Batch  799/1077 - Validation Accuracy:  0.946, Loss:  0.036
# Epoch  25 Batch  899/1077 - Train Accuracy:  0.945, Loss:  0.035
# Epoch  25 Batch  899/1077 - Validation Accuracy:  0.940, Loss:  0.035
# Epoch  25 Batch  999/1077 - Train Accuracy:  0.936, Loss:  0.033
# Epoch  25 Batch  999/1077 - Validation Accuracy:  0.939, Loss:  0.033
# Epoch  26 Batch   23/1077 - Train Accuracy:  0.932, Loss:  0.026
# Epoch  26 Batch   23/1077 - Validation Accuracy:  0.933, Loss:  0.026
# Epoch  26 Batch  123/1077 - Train Accuracy:  0.940, Loss:  0.024
# Epoch  26 Batch  123/1077 - Validation Accuracy:  0.937, Loss:  0.024
# Epoch  26 Batch  223/1077 - Train Accuracy:  0.942, Loss:  0.024
# Epoch  26 Batch  223/1077 - Validation Accuracy:  0.943, Loss:  0.024
# Epoch  26 Batch  323/1077 - Train Accuracy:  0.970, Loss:  0.028
# Epoch  26 Batch  323/1077 - Validation Accuracy:  0.941, Loss:  0.028
# Epoch  26 Batch  423/1077 - Train Accuracy:  0.959, Loss:  0.027
# Epoch  26 Batch  423/1077 - Validation Accuracy:  0.929, Loss:  0.027
# Epoch  26 Batch  523/1077 - Train Accuracy:  0.939, Loss:  0.025
# Epoch  26 Batch  523/1077 - Validation Accuracy:  0.936, Loss:  0.025
# Epoch  26 Batch  623/1077 - Train Accuracy:  0.914, Loss:  0.035
# Epoch  26 Batch  623/1077 - Validation Accuracy:  0.938, Loss:  0.035
# Epoch  26 Batch  723/1077 - Train Accuracy:  0.947, Loss:  0.029
# Epoch  26 Batch  723/1077 - Validation Accuracy:  0.932, Loss:  0.029
# Epoch  26 Batch  823/1077 - Train Accuracy:  0.944, Loss:  0.027
# Epoch  26 Batch  823/1077 - Validation Accuracy:  0.949, Loss:  0.027
# Epoch  26 Batch  923/1077 - Train Accuracy:  0.961, Loss:  0.020
# Epoch  26 Batch  923/1077 - Validation Accuracy:  0.950, Loss:  0.020
# Epoch  26 Batch 1023/1077 - Train Accuracy:  0.932, Loss:  0.034
# Epoch  26 Batch 1023/1077 - Validation Accuracy:  0.930, Loss:  0.034
# Epoch  27 Batch   47/1077 - Train Accuracy:  0.961, Loss:  0.025
# Epoch  27 Batch   47/1077 - Validation Accuracy:  0.952, Loss:  0.025
# Epoch  27 Batch  147/1077 - Train Accuracy:  0.926, Loss:  0.031
# Epoch  27 Batch  147/1077 - Validation Accuracy:  0.952, Loss:  0.031
# Epoch  27 Batch  247/1077 - Train Accuracy:  0.923, Loss:  0.034
# Epoch  27 Batch  247/1077 - Validation Accuracy:  0.935, Loss:  0.034
# Epoch  27 Batch  347/1077 - Train Accuracy:  0.962, Loss:  0.020
# Epoch  27 Batch  347/1077 - Validation Accuracy:  0.938, Loss:  0.020
# Epoch  27 Batch  447/1077 - Train Accuracy:  0.925, Loss:  0.023
# Epoch  27 Batch  447/1077 - Validation Accuracy:  0.941, Loss:  0.023
# Epoch  27 Batch  547/1077 - Train Accuracy:  0.961, Loss:  0.022
# Epoch  27 Batch  547/1077 - Validation Accuracy:  0.933, Loss:  0.022
# Epoch  27 Batch  647/1077 - Train Accuracy:  0.933, Loss:  0.030
# Epoch  27 Batch  647/1077 - Validation Accuracy:  0.943, Loss:  0.030
# Epoch  27 Batch  747/1077 - Train Accuracy:  0.948, Loss:  0.016
# Epoch  27 Batch  747/1077 - Validation Accuracy:  0.930, Loss:  0.016
# Epoch  27 Batch  847/1077 - Train Accuracy:  0.932, Loss:  0.031
# Epoch  27 Batch  847/1077 - Validation Accuracy:  0.945, Loss:  0.031
# Epoch  27 Batch  947/1077 - Train Accuracy:  0.936, Loss:  0.023
# Epoch  27 Batch  947/1077 - Validation Accuracy:  0.945, Loss:  0.023
# Epoch  27 Batch 1047/1077 - Train Accuracy:  0.960, Loss:  0.022
# Epoch  27 Batch 1047/1077 - Validation Accuracy:  0.954, Loss:  0.022
# Epoch  28 Batch   71/1077 - Train Accuracy:  0.959, Loss:  0.018
# Epoch  28 Batch   71/1077 - Validation Accuracy:  0.951, Loss:  0.018
# Epoch  28 Batch  171/1077 - Train Accuracy:  0.941, Loss:  0.029
# Epoch  28 Batch  171/1077 - Validation Accuracy:  0.926, Loss:  0.029
# Epoch  28 Batch  271/1077 - Train Accuracy:  0.957, Loss:  0.022
# Epoch  28 Batch  271/1077 - Validation Accuracy:  0.953, Loss:  0.022
# Epoch  28 Batch  371/1077 - Train Accuracy:  0.958, Loss:  0.023
# Epoch  28 Batch  371/1077 - Validation Accuracy:  0.926, Loss:  0.023
# Epoch  28 Batch  471/1077 - Train Accuracy:  0.952, Loss:  0.021
# Epoch  28 Batch  471/1077 - Validation Accuracy:  0.930, Loss:  0.021
# Epoch  28 Batch  571/1077 - Train Accuracy:  0.938, Loss:  0.022
# Epoch  28 Batch  571/1077 - Validation Accuracy:  0.945, Loss:  0.022
# Epoch  28 Batch  671/1077 - Train Accuracy:  0.958, Loss:  0.027
# Epoch  28 Batch  671/1077 - Validation Accuracy:  0.944, Loss:  0.027
# Epoch  28 Batch  771/1077 - Train Accuracy:  0.942, Loss:  0.029
# Epoch  28 Batch  771/1077 - Validation Accuracy:  0.933, Loss:  0.029
# Epoch  28 Batch  871/1077 - Train Accuracy:  0.937, Loss:  0.024
# Epoch  28 Batch  871/1077 - Validation Accuracy:  0.944, Loss:  0.024
# Epoch  28 Batch  971/1077 - Train Accuracy:  0.947, Loss:  0.043
# Epoch  28 Batch  971/1077 - Validation Accuracy:  0.948, Loss:  0.043
# Epoch  28 Batch 1071/1077 - Train Accuracy:  0.950, Loss:  0.024
# Epoch  28 Batch 1071/1077 - Validation Accuracy:  0.946, Loss:  0.024
# Epoch  29 Batch   95/1077 - Train Accuracy:  0.953, Loss:  0.026
# Epoch  29 Batch   95/1077 - Validation Accuracy:  0.941, Loss:  0.026
# Epoch  29 Batch  195/1077 - Train Accuracy:  0.936, Loss:  0.021
# Epoch  29 Batch  195/1077 - Validation Accuracy:  0.934, Loss:  0.021
# Epoch  29 Batch  295/1077 - Train Accuracy:  0.931, Loss:  0.032
# Epoch  29 Batch  295/1077 - Validation Accuracy:  0.945, Loss:  0.032
# Epoch  29 Batch  395/1077 - Train Accuracy:  0.953, Loss:  0.023
# Epoch  29 Batch  395/1077 - Validation Accuracy:  0.933, Loss:  0.023
# Epoch  29 Batch  495/1077 - Train Accuracy:  0.950, Loss:  0.020
# Epoch  29 Batch  495/1077 - Validation Accuracy:  0.934, Loss:  0.020
# Epoch  29 Batch  595/1077 - Train Accuracy:  0.968, Loss:  0.019
# Epoch  29 Batch  595/1077 - Validation Accuracy:  0.951, Loss:  0.019
# Epoch  29 Batch  695/1077 - Train Accuracy:  0.941, Loss:  0.027
# Epoch  29 Batch  695/1077 - Validation Accuracy:  0.945, Loss:  0.027
# Epoch  29 Batch  795/1077 - Train Accuracy:  0.949, Loss:  0.024
# Epoch  29 Batch  795/1077 - Validation Accuracy:  0.949, Loss:  0.024
# Epoch  29 Batch  895/1077 - Train Accuracy:  0.938, Loss:  0.023
# Epoch  29 Batch  895/1077 - Validation Accuracy:  0.941, Loss:  0.023
# Epoch  29 Batch  995/1077 - Train Accuracy:  0.935, Loss:  0.024
# Epoch  29 Batch  995/1077 - Validation Accuracy:  0.937, Loss:  0.024
# Epoch  30 Batch   19/1077 - Train Accuracy:  0.936, Loss:  0.027
# Epoch  30 Batch   19/1077 - Validation Accuracy:  0.952, Loss:  0.027
# Epoch  30 Batch  119/1077 - Train Accuracy:  0.926, Loss:  0.024
# Epoch  30 Batch  119/1077 - Validation Accuracy:  0.956, Loss:  0.024
# Epoch  30 Batch  219/1077 - Train Accuracy:  0.967, Loss:  0.018
# Epoch  30 Batch  219/1077 - Validation Accuracy:  0.935, Loss:  0.018
# Epoch  30 Batch  319/1077 - Train Accuracy:  0.943, Loss:  0.031
# Epoch  30 Batch  319/1077 - Validation Accuracy:  0.943, Loss:  0.031
# Epoch  30 Batch  419/1077 - Train Accuracy:  0.947, Loss:  0.021
# Epoch  30 Batch  419/1077 - Validation Accuracy:  0.931, Loss:  0.021
# Epoch  30 Batch  519/1077 - Train Accuracy:  0.941, Loss:  0.025
# Epoch  30 Batch  519/1077 - Validation Accuracy:  0.938, Loss:  0.025
# Epoch  30 Batch  619/1077 - Train Accuracy:  0.959, Loss:  0.018
# Epoch  30 Batch  619/1077 - Validation Accuracy:  0.945, Loss:  0.018
# Epoch  30 Batch  719/1077 - Train Accuracy:  0.939, Loss:  0.030
# Epoch  30 Batch  719/1077 - Validation Accuracy:  0.959, Loss:  0.030
# Epoch  30 Batch  819/1077 - Train Accuracy:  0.947, Loss:  0.025
# Epoch  30 Batch  819/1077 - Validation Accuracy:  0.949, Loss:  0.025
# Epoch  30 Batch  919/1077 - Train Accuracy:  0.965, Loss:  0.016
# Epoch  30 Batch  919/1077 - Validation Accuracy:  0.949, Loss:  0.016
# Epoch  30 Batch 1019/1077 - Train Accuracy:  0.926, Loss:  0.032
# Epoch  30 Batch 1019/1077 - Validation Accuracy:  0.942, Loss:  0.032
# Epoch  31 Batch   43/1077 - Train Accuracy:  0.966, Loss:  0.016
# Epoch  31 Batch   43/1077 - Validation Accuracy:  0.949, Loss:  0.016
# Epoch  31 Batch  143/1077 - Train Accuracy:  0.961, Loss:  0.019
# Epoch  31 Batch  143/1077 - Validation Accuracy:  0.947, Loss:  0.019
# Epoch  31 Batch  243/1077 - Train Accuracy:  0.953, Loss:  0.033
# Epoch  31 Batch  243/1077 - Validation Accuracy:  0.948, Loss:  0.033
# Epoch  31 Batch  343/1077 - Train Accuracy:  0.943, Loss:  0.027
# Epoch  31 Batch  343/1077 - Validation Accuracy:  0.942, Loss:  0.027
# Epoch  31 Batch  443/1077 - Train Accuracy:  0.965, Loss:  0.021
# Epoch  31 Batch  443/1077 - Validation Accuracy:  0.925, Loss:  0.021
# Epoch  31 Batch  543/1077 - Train Accuracy:  0.954, Loss:  0.020
# Epoch  31 Batch  543/1077 - Validation Accuracy:  0.957, Loss:  0.020
# Epoch  31 Batch  643/1077 - Train Accuracy:  0.953, Loss:  0.018
# Epoch  31 Batch  643/1077 - Validation Accuracy:  0.940, Loss:  0.018
# Epoch  31 Batch  743/1077 - Train Accuracy:  0.954, Loss:  0.022
# Epoch  31 Batch  743/1077 - Validation Accuracy:  0.942, Loss:  0.022
# Epoch  31 Batch  843/1077 - Train Accuracy:  0.949, Loss:  0.020
# Epoch  31 Batch  843/1077 - Validation Accuracy:  0.943, Loss:  0.020
# Epoch  31 Batch  943/1077 - Train Accuracy:  0.972, Loss:  0.019
# Epoch  31 Batch  943/1077 - Validation Accuracy:  0.938, Loss:  0.019
# Epoch  31 Batch 1043/1077 - Train Accuracy:  0.955, Loss:  0.033
# Epoch  31 Batch 1043/1077 - Validation Accuracy:  0.939, Loss:  0.033
# Epoch  32 Batch   67/1077 - Train Accuracy:  0.964, Loss:  0.021
# Epoch  32 Batch   67/1077 - Validation Accuracy:  0.942, Loss:  0.021
# Epoch  32 Batch  167/1077 - Train Accuracy:  0.946, Loss:  0.019
# Epoch  32 Batch  167/1077 - Validation Accuracy:  0.944, Loss:  0.019
# Epoch  32 Batch  267/1077 - Train Accuracy:  0.943, Loss:  0.019
# Epoch  32 Batch  267/1077 - Validation Accuracy:  0.945, Loss:  0.019
# Epoch  32 Batch  367/1077 - Train Accuracy:  0.964, Loss:  0.020
# Epoch  32 Batch  367/1077 - Validation Accuracy:  0.952, Loss:  0.020
# Epoch  32 Batch  467/1077 - Train Accuracy:  0.960, Loss:  0.022
# Epoch  32 Batch  467/1077 - Validation Accuracy:  0.938, Loss:  0.022
# Epoch  32 Batch  567/1077 - Train Accuracy:  0.946, Loss:  0.024
# Epoch  32 Batch  567/1077 - Validation Accuracy:  0.941, Loss:  0.024
# Epoch  32 Batch  667/1077 - Train Accuracy:  0.960, Loss:  0.021
# Epoch  32 Batch  667/1077 - Validation Accuracy:  0.945, Loss:  0.021
# Epoch  32 Batch  767/1077 - Train Accuracy:  0.957, Loss:  0.021
# Epoch  32 Batch  767/1077 - Validation Accuracy:  0.945, Loss:  0.021
# Epoch  32 Batch  867/1077 - Train Accuracy:  0.921, Loss:  0.050
# Epoch  32 Batch  867/1077 - Validation Accuracy:  0.941, Loss:  0.050
# Epoch  32 Batch  967/1077 - Train Accuracy:  0.948, Loss:  0.022
# Epoch  32 Batch  967/1077 - Validation Accuracy:  0.945, Loss:  0.022
# Epoch  32 Batch 1067/1077 - Train Accuracy:  0.946, Loss:  0.025
# Epoch  32 Batch 1067/1077 - Validation Accuracy:  0.951, Loss:  0.025
# Epoch  33 Batch   91/1077 - Train Accuracy:  0.955, Loss:  0.019
# ...
# Epoch  49 Batch   75/1077 - Train Accuracy:  0.957, Loss:  0.021
# Epoch  49 Batch   75/1077 - Validation Accuracy:  0.957, Loss:  0.021
# Epoch  49 Batch  175/1077 - Train Accuracy:  0.946, Loss:  0.016
# Epoch  49 Batch  175/1077 - Validation Accuracy:  0.951, Loss:  0.016
# Epoch  49 Batch  275/1077 - Train Accuracy:  0.973, Loss:  0.009
# Epoch  49 Batch  275/1077 - Validation Accuracy:  0.967, Loss:  0.009
# Epoch  49 Batch  375/1077 - Train Accuracy:  0.964, Loss:  0.012
# Epoch  49 Batch  375/1077 - Validation Accuracy:  0.952, Loss:  0.012
# Epoch  49 Batch  475/1077 - Train Accuracy:  0.957, Loss:  0.015
# Epoch  49 Batch  475/1077 - Validation Accuracy:  0.955, Loss:  0.015
# Epoch  49 Batch  575/1077 - Train Accuracy:  0.952, Loss:  0.015
# Epoch  49 Batch  575/1077 - Validation Accuracy:  0.952, Loss:  0.015
# Epoch  49 Batch  675/1077 - Train Accuracy:  0.951, Loss:  0.018
# Epoch  49 Batch  675/1077 - Validation Accuracy:  0.951, Loss:  0.018
# Epoch  49 Batch  775/1077 - Train Accuracy:  0.964, Loss:  0.013
# Epoch  49 Batch  775/1077 - Validation Accuracy:  0.960, Loss:  0.013
# Epoch  49 Batch  875/1077 - Train Accuracy:  0.974, Loss:  0.015
# Epoch  49 Batch  875/1077 - Validation Accuracy:  0.957, Loss:  0.015
# Epoch  49 Batch  975/1077 - Train Accuracy:  0.965, Loss:  0.013
# Epoch  49 Batch  975/1077 - Validation Accuracy:  0.968, Loss:  0.013
# Epoch  49 Batch 1075/1077 - Train Accuracy:  0.966, Loss:  0.014
# Epoch  49 Batch 1075/1077 - Validation Accuracy:  0.958, Loss:  0.014
# Epoch  50 Batch   99/1077 - Train Accuracy:  0.969, Loss:  0.014
# Epoch  50 Batch   99/1077 - Validation Accuracy:  0.953, Loss:  0.014
# Epoch  50 Batch  199/1077 - Train Accuracy:  0.976, Loss:  0.009
# Epoch  50 Batch  199/1077 - Validation Accuracy:  0.961, Loss:  0.009
# Epoch  50 Batch  299/1077 - Train Accuracy:  0.961, Loss:  0.016
# Epoch  50 Batch  299/1077 - Validation Accuracy:  0.968, Loss:  0.016
# Epoch  50 Batch  399/1077 - Train Accuracy:  0.956, Loss:  0.013
# Epoch  50 Batch  399/1077 - Validation Accuracy:  0.949, Loss:  0.013
# Epoch  50 Batch  499/1077 - Train Accuracy:  0.960, Loss:  0.013
# Epoch  50 Batch  499/1077 - Validation Accuracy:  0.955, Loss:  0.013
# Epoch  50 Batch  599/1077 - Train Accuracy:  0.946, Loss:  0.027
# Epoch  50 Batch  599/1077 - Validation Accuracy:  0.958, Loss:  0.027
# Epoch  50 Batch  699/1077 - Train Accuracy:  0.970, Loss:  0.010
# Epoch  50 Batch  699/1077 - Validation Accuracy:  0.958, Loss:  0.010
# Epoch  50 Batch  799/1077 - Train Accuracy:  0.960, Loss:  0.014
# Epoch  50 Batch  799/1077 - Validation Accuracy:  0.970, Loss:  0.014
# Epoch  50 Batch  899/1077 - Train Accuracy:  0.965, Loss:  0.015
# Epoch  50 Batch  899/1077 - Validation Accuracy:  0.951, Loss:  0.015
# Epoch  50 Batch  999/1077 - Train Accuracy:  0.959, Loss:  0.016
# Epoch  50 Batch  999/1077 - Validation Accuracy:  0.967, Loss:  0.016
# Epoch  51 Batch   23/1077 - Train Accuracy:  0.978, Loss:  0.009
# Epoch  51 Batch   23/1077 - Validation Accuracy:  0.959, Loss:  0.009
# Epoch  51 Batch  123/1077 - Train Accuracy:  0.968, Loss:  0.013
# Epoch  51 Batch  123/1077 - Validation Accuracy:  0.962, Loss:  0.013
# Epoch  51 Batch  223/1077 - Train Accuracy:  0.966, Loss:  0.010
# Epoch  51 Batch  223/1077 - Validation Accuracy:  0.948, Loss:  0.010
# Epoch  51 Batch  323/1077 - Train Accuracy:  0.956, Loss:  0.016
# Epoch  51 Batch  323/1077 - Validation Accuracy:  0.961, Loss:  0.016
# Epoch  51 Batch  423/1077 - Train Accuracy:  0.958, Loss:  0.014
# Epoch  51 Batch  423/1077 - Validation Accuracy:  0.962, Loss:  0.014
# Epoch  51 Batch  523/1077 - Train Accuracy:  0.958, Loss:  0.011
# Epoch  51 Batch  523/1077 - Validation Accuracy:  0.953, Loss:  0.011
# Epoch  51 Batch  623/1077 - Train Accuracy:  0.964, Loss:  0.018
# Epoch  51 Batch  623/1077 - Validation Accuracy:  0.956, Loss:  0.018
# Epoch  51 Batch  723/1077 - Train Accuracy:  0.968, Loss:  0.012
# Epoch  51 Batch  723/1077 - Validation Accuracy:  0.963, Loss:  0.012
# Epoch  51 Batch  823/1077 - Train Accuracy:  0.970, Loss:  0.017
# Epoch  51 Batch  823/1077 - Validation Accuracy:  0.972, Loss:  0.017
# Epoch  51 Batch  923/1077 - Train Accuracy:  0.972, Loss:  0.008
# Epoch  51 Batch  923/1077 - Validation Accuracy:  0.955, Loss:  0.008
# Epoch  51 Batch 1023/1077 - Train Accuracy:  0.958, Loss:  0.021
# Epoch  51 Batch 1023/1077 - Validation Accuracy:  0.962, Loss:  0.021
# Epoch  52 Batch   47/1077 - Train Accuracy:  0.971, Loss:  0.011
# Epoch  52 Batch   47/1077 - Validation Accuracy:  0.975, Loss:  0.011
# Epoch  52 Batch  147/1077 - Train Accuracy:  0.947, Loss:  0.017
# Epoch  52 Batch  147/1077 - Validation Accuracy:  0.968, Loss:  0.017
# Epoch  52 Batch  247/1077 - Train Accuracy:  0.948, Loss:  0.019
# Epoch  52 Batch  247/1077 - Validation Accuracy:  0.961, Loss:  0.019
# Epoch  52 Batch  347/1077 - Train Accuracy:  0.972, Loss:  0.008
# Epoch  52 Batch  347/1077 - Validation Accuracy:  0.961, Loss:  0.008
# Epoch  52 Batch  447/1077 - Train Accuracy:  0.966, Loss:  0.012
# Epoch  52 Batch  447/1077 - Validation Accuracy:  0.948, Loss:  0.012
# Epoch  52 Batch  547/1077 - Train Accuracy:  0.976, Loss:  0.010
# Epoch  52 Batch  547/1077 - Validation Accuracy:  0.961, Loss:  0.010
# Epoch  52 Batch  647/1077 - Train Accuracy:  0.964, Loss:  0.013
# Epoch  52 Batch  647/1077 - Validation Accuracy:  0.953, Loss:  0.013
# Epoch  52 Batch  747/1077 - Train Accuracy:  0.968, Loss:  0.010
# Epoch  52 Batch  747/1077 - Validation Accuracy:  0.970, Loss:  0.010
# Epoch  52 Batch  847/1077 - Train Accuracy:  0.968, Loss:  0.013
# Epoch  52 Batch  847/1077 - Validation Accuracy:  0.959, Loss:  0.013
# Epoch  52 Batch  947/1077 - Train Accuracy:  0.971, Loss:  0.010
# Epoch  52 Batch  947/1077 - Validation Accuracy:  0.976, Loss:  0.010
# Epoch  52 Batch 1047/1077 - Train Accuracy:  0.979, Loss:  0.008
# Epoch  52 Batch 1047/1077 - Validation Accuracy:  0.944, Loss:  0.008
# Epoch  53 Batch   71/1077 - Train Accuracy:  0.979, Loss:  0.008
# Epoch  53 Batch   71/1077 - Validation Accuracy:  0.961, Loss:  0.008
# Epoch  53 Batch  171/1077 - Train Accuracy:  0.973, Loss:  0.012
# Epoch  53 Batch  171/1077 - Validation Accuracy:  0.955, Loss:  0.012
# Epoch  53 Batch  271/1077 - Train Accuracy:  0.959, Loss:  0.011
# Epoch  53 Batch  271/1077 - Validation Accuracy:  0.958, Loss:  0.011
# Epoch  53 Batch  371/1077 - Train Accuracy:  0.975, Loss:  0.009
# Epoch  53 Batch  371/1077 - Validation Accuracy:  0.962, Loss:  0.009
# Epoch  53 Batch  471/1077 - Train Accuracy:  0.971, Loss:  0.013
# Epoch  53 Batch  471/1077 - Validation Accuracy:  0.958, Loss:  0.013
# Epoch  53 Batch  571/1077 - Train Accuracy:  0.956, Loss:  0.011
# Epoch  53 Batch  571/1077 - Validation Accuracy:  0.956, Loss:  0.011
# Epoch  53 Batch  671/1077 - Train Accuracy:  0.974, Loss:  0.013
# Epoch  53 Batch  671/1077 - Validation Accuracy:  0.967, Loss:  0.013
# Epoch  53 Batch  771/1077 - Train Accuracy:  0.962, Loss:  0.017
# Epoch  53 Batch  771/1077 - Validation Accuracy:  0.960, Loss:  0.017
# Epoch  53 Batch  871/1077 - Train Accuracy:  0.956, Loss:  0.011
# Epoch  53 Batch  871/1077 - Validation Accuracy:  0.958, Loss:  0.011
# Epoch  53 Batch  971/1077 - Train Accuracy:  0.961, Loss:  0.025
# Epoch  53 Batch  971/1077 - Validation Accuracy:  0.972, Loss:  0.025
# Epoch  53 Batch 1071/1077 - Train Accuracy:  0.962, Loss:  0.018
# Epoch  53 Batch 1071/1077 - Validation Accuracy:  0.956, Loss:  0.018
# Epoch  54 Batch   95/1077 - Train Accuracy:  0.975, Loss:  0.010
# Epoch  54 Batch   95/1077 - Validation Accuracy:  0.969, Loss:  0.010
# Epoch  54 Batch  195/1077 - Train Accuracy:  0.966, Loss:  0.007
# Epoch  54 Batch  195/1077 - Validation Accuracy:  0.957, Loss:  0.007
# Epoch  54 Batch  295/1077 - Train Accuracy:  0.971, Loss:  0.014
# Epoch  54 Batch  295/1077 - Validation Accuracy:  0.958, Loss:  0.014
# Epoch  54 Batch  395/1077 - Train Accuracy:  0.980, Loss:  0.008
# Epoch  54 Batch  395/1077 - Validation Accuracy:  0.960, Loss:  0.008
# Epoch  54 Batch  495/1077 - Train Accuracy:  0.978, Loss:  0.006
# Epoch  54 Batch  495/1077 - Validation Accuracy:  0.963, Loss:  0.006
# Epoch  54 Batch  595/1077 - Train Accuracy:  0.971, Loss:  0.010
# Epoch  54 Batch  595/1077 - Validation Accuracy:  0.965, Loss:  0.010
# Epoch  54 Batch  695/1077 - Train Accuracy:  0.966, Loss:  0.017
# Epoch  54 Batch  695/1077 - Validation Accuracy:  0.967, Loss:  0.017
# Epoch  54 Batch  795/1077 - Train Accuracy:  0.954, Loss:  0.019
# Epoch  54 Batch  795/1077 - Validation Accuracy:  0.960, Loss:  0.019
# Epoch  54 Batch  895/1077 - Train Accuracy:  0.954, Loss:  0.011
# Epoch  54 Batch  895/1077 - Validation Accuracy:  0.962, Loss:  0.011
# Epoch  54 Batch  995/1077 - Train Accuracy:  0.964, Loss:  0.010
# Epoch  54 Batch  995/1077 - Validation Accuracy:  0.956, Loss:  0.010
# Epoch  55 Batch   19/1077 - Train Accuracy:  0.955, Loss:  0.016
# Epoch  55 Batch   19/1077 - Validation Accuracy:  0.958, Loss:  0.016
# Epoch  55 Batch  119/1077 - Train Accuracy:  0.958, Loss:  0.011
# Epoch  55 Batch  119/1077 - Validation Accuracy:  0.954, Loss:  0.011
# Epoch  55 Batch  219/1077 - Train Accuracy:  0.972, Loss:  0.009
# Epoch  55 Batch  219/1077 - Validation Accuracy:  0.968, Loss:  0.009
# Epoch  55 Batch  319/1077 - Train Accuracy:  0.962, Loss:  0.015
# Epoch  55 Batch  319/1077 - Validation Accuracy:  0.962, Loss:  0.015
# Epoch  55 Batch  419/1077 - Train Accuracy:  0.948, Loss:  0.013
# Epoch  55 Batch  419/1077 - Validation Accuracy:  0.966, Loss:  0.013
# Epoch  55 Batch  519/1077 - Train Accuracy:  0.958, Loss:  0.012
# Epoch  55 Batch  519/1077 - Validation Accuracy:  0.966, Loss:  0.012
# Epoch  55 Batch  619/1077 - Train Accuracy:  0.965, Loss:  0.009
# Epoch  55 Batch  619/1077 - Validation Accuracy:  0.966, Loss:  0.009
# Epoch  55 Batch  719/1077 - Train Accuracy:  0.960, Loss:  0.012
# Epoch  55 Batch  719/1077 - Validation Accuracy:  0.963, Loss:  0.012
# Epoch  55 Batch  819/1077 - Train Accuracy:  0.953, Loss:  0.012
# Epoch  55 Batch  819/1077 - Validation Accuracy:  0.973, Loss:  0.012
# Epoch  55 Batch  919/1077 - Train Accuracy:  0.980, Loss:  0.008
# Epoch  55 Batch  919/1077 - Validation Accuracy:  0.969, Loss:  0.008
# Epoch  55 Batch 1019/1077 - Train Accuracy:  0.954, Loss:  0.021
# Epoch  55 Batch 1019/1077 - Validation Accuracy:  0.968, Loss:  0.021
# Epoch  56 Batch   43/1077 - Train Accuracy:  0.985, Loss:  0.007
# Epoch  56 Batch   43/1077 - Validation Accuracy:  0.973, Loss:  0.007
# Epoch  56 Batch  143/1077 - Train Accuracy:  0.976, Loss:  0.008
# Epoch  56 Batch  143/1077 - Validation Accuracy:  0.963, Loss:  0.008
# Epoch  56 Batch  243/1077 - Train Accuracy:  0.961, Loss:  0.019
# Epoch  56 Batch  243/1077 - Validation Accuracy:  0.961, Loss:  0.019
# Epoch  56 Batch  343/1077 - Train Accuracy:  0.965, Loss:  0.012
# Epoch  56 Batch  343/1077 - Validation Accuracy:  0.963, Loss:  0.012
# Epoch  56 Batch  443/1077 - Train Accuracy:  0.981, Loss:  0.007
# Epoch  56 Batch  443/1077 - Validation Accuracy:  0.956, Loss:  0.007
# Epoch  56 Batch  543/1077 - Train Accuracy:  0.977, Loss:  0.009
# Epoch  56 Batch  543/1077 - Validation Accuracy:  0.961, Loss:  0.009
# Epoch  56 Batch  643/1077 - Train Accuracy:  0.970, Loss:  0.009
# Epoch  56 Batch  643/1077 - Validation Accuracy:  0.967, Loss:  0.009
# Epoch  56 Batch  743/1077 - Train Accuracy:  0.986, Loss:  0.009
# Epoch  56 Batch  743/1077 - Validation Accuracy:  0.962, Loss:  0.009
# Epoch  56 Batch  843/1077 - Train Accuracy:  0.974, Loss:  0.010
# Epoch  56 Batch  843/1077 - Validation Accuracy:  0.969, Loss:  0.010
# Epoch  56 Batch  943/1077 - Train Accuracy:  0.975, Loss:  0.010
# Epoch  56 Batch  943/1077 - Validation Accuracy:  0.970, Loss:  0.010
# Epoch  56 Batch 1043/1077 - Train Accuracy:  0.961, Loss:  0.014
# Epoch  56 Batch 1043/1077 - Validation Accuracy:  0.960, Loss:  0.014
# Epoch  57 Batch   67/1077 - Train Accuracy:  0.964, Loss:  0.013
# Epoch  57 Batch   67/1077 - Validation Accuracy:  0.969, Loss:  0.013
# Epoch  57 Batch  167/1077 - Train Accuracy:  0.962, Loss:  0.010
# Epoch  57 Batch  167/1077 - Validation Accuracy:  0.949, Loss:  0.010
# Epoch  57 Batch  267/1077 - Train Accuracy:  0.970, Loss:  0.010
# Epoch  57 Batch  267/1077 - Validation Accuracy:  0.963, Loss:  0.010
# Epoch  57 Batch  367/1077 - Train Accuracy:  0.974, Loss:  0.007
# Epoch  57 Batch  367/1077 - Validation Accuracy:  0.961, Loss:  0.007
# Epoch  57 Batch  467/1077 - Train Accuracy:  0.973, Loss:  0.011
# Epoch  57 Batch  467/1077 - Validation Accuracy:  0.950, Loss:  0.011
# Epoch  57 Batch  567/1077 - Train Accuracy:  0.972, Loss:  0.013
# Epoch  57 Batch  567/1077 - Validation Accuracy:  0.962, Loss:  0.013
# Epoch  57 Batch  667/1077 - Train Accuracy:  0.983, Loss:  0.010
# Epoch  57 Batch  667/1077 - Validation Accuracy:  0.967, Loss:  0.010
# Epoch  57 Batch  767/1077 - Train Accuracy:  0.970, Loss:  0.011
# Epoch  57 Batch  767/1077 - Validation Accuracy:  0.952, Loss:  0.011
# Epoch  57 Batch  867/1077 - Train Accuracy:  0.945, Loss:  0.033
# Epoch  57 Batch  867/1077 - Validation Accuracy:  0.960, Loss:  0.033
# Epoch  57 Batch  967/1077 - Train Accuracy:  0.961, Loss:  0.011
# Epoch  57 Batch  967/1077 - Validation Accuracy:  0.973, Loss:  0.011
# Epoch  57 Batch 1067/1077 - Train Accuracy:  0.960, Loss:  0.014
# Epoch  57 Batch 1067/1077 - Validation Accuracy:  0.967, Loss:  0.014
# Epoch  58 Batch   91/1077 - Train Accuracy:  0.971, Loss:  0.012
# Epoch  58 Batch   91/1077 - Validation Accuracy:  0.965, Loss:  0.012
# Epoch  58 Batch  191/1077 - Train Accuracy:  0.958, Loss:  0.009
# Epoch  58 Batch  191/1077 - Validation Accuracy:  0.955, Loss:  0.009
# Epoch  58 Batch  291/1077 - Train Accuracy:  0.951, Loss:  0.020
# Epoch  58 Batch  291/1077 - Validation Accuracy:  0.960, Loss:  0.020
# Epoch  58 Batch  391/1077 - Train Accuracy:  0.973, Loss:  0.010
# Epoch  58 Batch  391/1077 - Validation Accuracy:  0.974, Loss:  0.010
# Epoch  58 Batch  491/1077 - Train Accuracy:  0.968, Loss:  0.014
# Epoch  58 Batch  491/1077 - Validation Accuracy:  0.960, Loss:  0.014
# Epoch  58 Batch  591/1077 - Train Accuracy:  0.961, Loss:  0.011
# Epoch  58 Batch  591/1077 - Validation Accuracy:  0.960, Loss:  0.011
# Epoch  58 Batch  691/1077 - Train Accuracy:  0.971, Loss:  0.009
# Epoch  58 Batch  691/1077 - Validation Accuracy:  0.956, Loss:  0.009
# Epoch  58 Batch  791/1077 - Train Accuracy:  0.957, Loss:  0.011
# Epoch  58 Batch  791/1077 - Validation Accuracy:  0.960, Loss:  0.011
# Epoch  58 Batch  891/1077 - Train Accuracy:  0.977, Loss:  0.008
# Epoch  58 Batch  891/1077 - Validation Accuracy:  0.955, Loss:  0.008
# Epoch  58 Batch  991/1077 - Train Accuracy:  0.957, Loss:  0.011
# Epoch  58 Batch  991/1077 - Validation Accuracy:  0.965, Loss:  0.011
# Epoch  59 Batch   15/1077 - Train Accuracy:  0.970, Loss:  0.013
# Epoch  59 Batch   15/1077 - Validation Accuracy:  0.967, Loss:  0.013
# Epoch  59 Batch  115/1077 - Train Accuracy:  0.962, Loss:  0.015
# Epoch  59 Batch  115/1077 - Validation Accuracy:  0.969, Loss:  0.015
# Epoch  59 Batch  215/1077 - Train Accuracy:  0.952, Loss:  0.016
# Epoch  59 Batch  215/1077 - Validation Accuracy:  0.970, Loss:  0.016
# Epoch  59 Batch  315/1077 - Train Accuracy:  0.967, Loss:  0.010
# Epoch  59 Batch  315/1077 - Validation Accuracy:  0.965, Loss:  0.010
# Epoch  59 Batch  415/1077 - Train Accuracy:  0.964, Loss:  0.018
# Epoch  59 Batch  415/1077 - Validation Accuracy:  0.964, Loss:  0.018
# Epoch  59 Batch  515/1077 - Train Accuracy:  0.976, Loss:  0.010
# Epoch  59 Batch  515/1077 - Validation Accuracy:  0.963, Loss:  0.010
# Epoch  59 Batch  615/1077 - Train Accuracy:  0.978, Loss:  0.008
# Epoch  59 Batch  615/1077 - Validation Accuracy:  0.963, Loss:  0.008
# Epoch  59 Batch  715/1077 - Train Accuracy:  0.964, Loss:  0.010
# Epoch  59 Batch  715/1077 - Validation Accuracy:  0.959, Loss:  0.010
# Epoch  59 Batch  815/1077 - Train Accuracy:  0.967, Loss:  0.012
# Epoch  59 Batch  815/1077 - Validation Accuracy:  0.964, Loss:  0.012
# Epoch  59 Batch  915/1077 - Train Accuracy:  0.959, Loss:  0.009
# Epoch  59 Batch  915/1077 - Validation Accuracy:  0.963, Loss:  0.009
# Epoch  59 Batch 1015/1077 - Train Accuracy:  0.963, Loss:  0.015
# Epoch  59 Batch 1015/1077 - Validation Accuracy:  0.962, Loss:  0.015
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    ret =[]
    for word in sentence.lower().split():
        ret.append( vocab_to_int.get(word,vocab_to_int['<UNK>'] )  )
        
    return ret


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('logits:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence], keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in np.argmax(translate_logits, 1)]))
print('  French Words: {}'.format([target_int_to_vocab[i] for i in np.argmax(translate_logits, 1)]))
# Out:
# Input
#   Word Ids:      [93, 142, 78, 221, 178, 149, 46]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [318, 348, 315, 200, 1]
#   French Words: ['février', 'une', 'froid', '.', '<EOS>']

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
